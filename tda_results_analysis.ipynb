# %%
import os
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Accuracy Matrix

# %%
df = pd.read_csv("novels_ph_results/accuracy_matrix_wasserstein.csv", encoding="latin-1")

# %%
df = df[df["Unnamed: 0"] != "NA (1)"]
df.drop(["NA (1)"], axis=1, inplace=True)

# %%
df = df.round(2)

# %%
df
# Out:
#                Unnamed: 0  Charles Dickens (17)  Émile Zola (17)  \
# 0    Charles Dickens (17)                   NaN             69.6
# 1         Émile Zola (17)                  69.6              NaN
# 2  Fyodor Dostoyevsky (8)                  37.8             64.8
# 3         Jane Austen (6)                  55.7             60.4
# 4          Mark Twain (8)                  54.4             59.8
# 6       Walter Scott (18)                  72.1             64.2
#
#    Fyodor Dostoyevsky (8)  Jane Austen (6)  Mark Twain (8)  Walter Scott (18)  \
# 0                    37.8             55.7            54.4               72.1
# 1                    64.8             60.4            59.8               64.2
# 2                     NaN             54.5            50.3               62.7
# 3                    54.5              NaN            41.0               39.2
# 4                    50.3             41.0             NaN               44.0
# ...

# %%
df = df.iloc[:,:]

# %%
df.style.background_gradient(cmap='twilight')
# Out:
# <style  type="text/css" >
# #T_4c6cfb3a_a7d3_11eb_bd1e_e8d8d13d9039row0_col1,#T_4c6cfb3a_a7d3_11eb_bd1e_e8d8d13d9039row1_col2,#T_4c6cfb3a_a7d3_11eb_bd1e_e8d8d13d9039row2_col3,#T_4c6cfb3a_a7d3_11eb_bd1e_e8d8d13d9039row3_col4,#T_4c6cfb3a_a7d3_11eb_bd1e_e8d8d13d9039row4_col5,#T_4c6cfb3a_a7d3_11eb_bd1e_e8d8d13d9039row5_col6{
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# ## Results Summary

# %%
pd.set_option('display.max_rows', 100)

# %%
df_summary = pd.read_csv("novels_ph_results/results_summary_wasserstein.csv", encoding="latin-1")

# %%
df_summary
# Out:
#                                               novel              writer  \
# 0          Uncle's Dream; and The Permanent Husband  Fyodor Dostoyevsky
# 1                              A Tale of Two Cities     Charles Dickens
# 2                                      Oliver Twist     Charles Dickens
# 3                                    Theresa Raquin          Émile Zola
# 4                                Great Expectations     Charles Dickens
# 5                        The Uncommercial Traveller     Charles Dickens
# 6                                       Roughing It          Mark Twain
# 7                              Crime and Punishment  Fyodor Dostoyevsky
# 8                            The Rush for the Spoil          Émile Zola
# 9                         The Stolen White Elephant          Mark Twain
# 10                             The Fat and the Thin          Émile Zola
# 11                   White Nights and Other Stories  Fyodor Dostoyevsky
# ...

# %% [markdown]
# Reference:
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
