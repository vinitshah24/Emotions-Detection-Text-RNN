# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("detected_emotions_output.csv")

# %%
df
# Out:
#                                                    text    joy  sadness  \
# 0                    All children, except one, grow up.  0.566    0.429
# 1     They soon know that they will grow up, and the...  0.175    0.494
# 2     One day when she was two years old she was pla...  0.183    0.276
# 3     I suppose she must have looked rather delightf...  0.460    0.931
# 4     This was all that passed between them on the s...  0.205    0.562
# ...                                                 ...    ...      ...
# 3036  Of course in the end Wendy let them fly away t...  0.370    0.451
# 3037  Our last glimpse of her shows her at the windo...  0.522    0.337
# 3038  As you look at Wendy, you may see her hair bec...  0.682    0.706
# 3039  Jane is now a common grown-up, with a daughter...  0.616    0.822
# 3040  When Margaret grows up she will have a daughte...  0.217    0.559
#
#       anger   love  thankfulness   fear
# 0     0.641  0.394         0.586  0.269
# 1     0.574  0.765         0.963  0.058
# 2     0.917  0.483         0.945  0.052
# 3     0.035  0.520         0.908  0.107
# 4     0.871  0.816         0.921  0.150
# ...     ...    ...           ...    ...
# 3036  0.004  0.409         0.147  0.191
# 3037  0.634  0.802         0.987  0.044
# 3038  0.802  0.891         0.892  0.018
# 3039  0.600  0.545         0.646  0.110
# 3040  0.167  0.974         0.552  0.118
#
# [3041 rows x 7 columns]

# %%
df['emotion'] = df[['joy','sadness','anger','love','thankfulness','fear']].idxmax(axis=1)

# %%
df
# Out:
#                                                    text    joy  sadness  \
# 0                    All children, except one, grow up.  0.566    0.429
# 1     They soon know that they will grow up, and the...  0.175    0.494
# 2     One day when she was two years old she was pla...  0.183    0.276
# 3     I suppose she must have looked rather delightf...  0.460    0.931
# 4     This was all that passed between them on the s...  0.205    0.562
# ...                                                 ...    ...      ...
# 3036  Of course in the end Wendy let them fly away t...  0.370    0.451
# 3037  Our last glimpse of her shows her at the windo...  0.522    0.337
# 3038  As you look at Wendy, you may see her hair bec...  0.682    0.706
# 3039  Jane is now a common grown-up, with a daughter...  0.616    0.822
# 3040  When Margaret grows up she will have a daughte...  0.217    0.559
#
#       anger   love  thankfulness   fear       emotion
# 0     0.641  0.394         0.586  0.269         anger
# 1     0.574  0.765         0.963  0.058  thankfulness
# 2     0.917  0.483         0.945  0.052  thankfulness
# 3     0.035  0.520         0.908  0.107       sadness
# 4     0.871  0.816         0.921  0.150  thankfulness
# ...     ...    ...           ...    ...           ...
# 3036  0.004  0.409         0.147  0.191       sadness
# 3037  0.634  0.802         0.987  0.044  thankfulness
# 3038  0.802  0.891         0.892  0.018  thankfulness
# 3039  0.600  0.545         0.646  0.110       sadness
# 3040  0.167  0.974         0.552  0.118          love
#
# [3041 rows x 8 columns]

# %%
df['count'] = df.emotion.groupby(df.emotion).transform('count')

# %%
df.head()
# Out:
#                                                 text    joy  sadness  anger  \
# 0                 All children, except one, grow up.  0.566    0.429  0.641
# 1  They soon know that they will grow up, and the...  0.175    0.494  0.574
# 2  One day when she was two years old she was pla...  0.183    0.276  0.917
# 3  I suppose she must have looked rather delightf...  0.460    0.931  0.035
# 4  This was all that passed between them on the s...  0.205    0.562  0.871
#
#     love  thankfulness   fear       emotion  count
# 0  0.394         0.586  0.269         anger    586
# 1  0.765         0.963  0.058  thankfulness   1028
# 2  0.483         0.945  0.052  thankfulness   1028
# 3  0.520         0.908  0.107       sadness    476
# 4  0.816         0.921  0.150  thankfulness   1028

# %%
emotion_name = df['emotion'].unique()
emotion_count = df['count'].unique()

# %%
plt.figure(figsize=(10,5))
g = sns.barplot(x=emotion_name, y=emotion_count)
